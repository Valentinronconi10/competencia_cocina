# %%
import sys
import os
sys.path.append(os.path.abspath(".."))
from src.cocina import simular_competencia

# %%
rounds = [{
'theme': 'Entrada',
'scores': {
'Valentina': {'judge_1': 8, 'judge_2': 7,
'judge_3': 9},
'Mateo': {'judge_1': 7, 'judge_2': 8,
'judge_3': 7},
'Camila': {'judge_1': 9, 'judge_2': 9,
'judge_3': 8},
'Santiago': {'judge_1': 6, 'judge_2': 7,
'judge_3': 6},
'Lucía': {'judge_1': 8, 'judge_2': 8,
'judge_3': 8},
}
},
{
'theme': 'Plato principal',
'scores': {
'Valentina': {'judge_1': 9, 'judge_2': 9,
'judge_3': 8},
'Mateo': {'judge_1': 8, 'judge_2': 7,
'judge_3': 9},
'Camila': {'judge_1': 7, 'judge_2': 6,
'judge_3': 7},
'Santiago': {'judge_1': 9, 'judge_2': 8,
'judge_3': 8},
'Lucía': {'judge_1': 7, 'judge_2': 8,
'judge_3': 7},
}
},
{
'theme': 'Postre','scores': {
'Valentina': {'judge_1': 7, 'judge_2': 8,
'judge_3': 7},
'Mateo': {'judge_1': 9, 'judge_2': 9,
'judge_3': 8},
'Camila': {'judge_1': 8, 'judge_2': 7,
'judge_3': 9},
'Santiago': {'judge_1': 7, 'judge_2': 7,
'judge_3': 6},
'Lucía': {'judge_1': 9, 'judge_2': 9,
'judge_3': 9},
}
},
{
'theme': 'Cocina internacional',
'scores': {
'Valentina': {'judge_1': 8, 'judge_2': 9,
'judge_3': 9},
'Mateo': {'judge_1': 7, 'judge_2': 6,
'judge_3': 7},
'Camila': {'judge_1': 9, 'judge_2': 8,
'judge_3': 8},
'Santiago': {'judge_1': 8, 'judge_2': 9,
'judge_3': 7},
'Lucía': {'judge_1': 7, 'judge_2': 7,
'judge_3': 8},
}
},
{
'theme': 'Final libre',
'scores': {
'Valentina': {'judge_1': 9, 'judge_2': 8,
'judge_3': 9},
'Mateo': {'judge_1': 8, 'judge_2': 9,
'judge_3': 8},
'Camila': {'judge_1': 7, 'judge_2': 7,
'judge_3': 7},
'Santiago': {'judge_1': 9, 'judge_2': 9,
'judge_3': 9},
'Lucía': {'judge_1': 8, 'judge_2': 8,
'judge_3': 7},
}
}
]

# %%
resultados, tabla_final = simular_competencia(rounds)
for tema,ganador,puntaje,tabla in resultados:
    print("\nRonda:", tema)
    print(f"Ganador: {ganador} con {puntaje} puntos")

    print("\nTabla de posiciones: ")
    for p,d in tabla.items():
        print(p,d)
print(resultados[0])
# Out:
# Ronda: Entrada
# Ganador: Camila con 26 puntos
#
# Tabla de posiciones:
# Valentina {'puntaje_total': 24, 'rondas_ganadas': 0, 'mejor_ronda': 24, 'rondas_jugadas': 1}
# Mateo {'puntaje_total': 22, 'rondas_ganadas': 0, 'mejor_ronda': 22, 'rondas_jugadas': 1}
# Camila {'puntaje_total': 26, 'rondas_ganadas': 1, 'mejor_ronda': 26, 'rondas_jugadas': 1}
# Santiago {'puntaje_total': 19, 'rondas_ganadas': 0, 'mejor_ronda': 19, 'rondas_jugadas': 1}
# Lucía {'puntaje_total': 24, 'rondas_ganadas': 0, 'mejor_ronda': 24, 'rondas_jugadas': 1}
#
# Ronda: Plato principal
# Ganador: Valentina con 26 puntos
#
# Tabla de posiciones:
# Valentina {'puntaje_total': 50, 'rondas_ganadas': 1, 'mejor_ronda': 26, 'rondas_jugadas': 2}
# Mateo {'puntaje_total': 46, 'rondas_ganadas': 0, 'mejor_ronda': 24, 'rondas_jugadas': 2}
# Camila {'puntaje_total': 46, 'rondas_ganadas': 1, 'mejor_ronda': 26, 'rondas_jugadas': 2}
# Santiago {'puntaje_total': 44, 'rondas_ganadas': 0, 'mejor_ronda': 25, 'rondas_jugadas': 2}
# Lucía {'puntaje_total': 46, 'rondas_ganadas': 0, 'mejor_ronda': 24, 'rondas_jugadas': 2}
#
# Ronda: Postre
# Ganador: Lucía con 27 puntos
#
# Tabla de posiciones:
# Valentina {'puntaje_total': 72, 'rondas_ganadas': 1, 'mejor_ronda': 26, 'rondas_jugadas': 3}
# Mateo {'puntaje_total': 72, 'rondas_ganadas': 0, 'mejor_ronda': 26, 'rondas_jugadas': 3}
# Camila {'puntaje_total': 70, 'rondas_ganadas': 1, 'mejor_ronda': 26, 'rondas_jugadas': 3}
# Santiago {'puntaje_total': 64, 'rondas_ganadas': 0, 'mejor_ronda': 25, 'rondas_jugadas': 3}
# Lucía {'puntaje_total': 73, 'rondas_ganadas': 1, 'mejor_ronda': 27, 'rondas_jugadas': 3}
#
# Ronda: Cocina internacional
# Ganador: Valentina con 26 puntos
#
# Tabla de posiciones:
# Valentina {'puntaje_total': 98, 'rondas_ganadas': 2, 'mejor_ronda': 26, 'rondas_jugadas': 4}
# Mateo {'puntaje_total': 92, 'rondas_ganadas': 0, 'mejor_ronda': 26, 'rondas_jugadas': 4}
# Camila {'puntaje_total': 95, 'rondas_ganadas': 1, 'mejor_ronda': 26, 'rondas_jugadas': 4}
# Santiago {'puntaje_total': 88, 'rondas_ganadas': 0, 'mejor_ronda': 25, 'rondas_jugadas': 4}
# Lucía {'puntaje_total': 95, 'rondas_ganadas': 1, 'mejor_ronda': 27, 'rondas_jugadas': 4}
#
# Ronda: Final libre
# Ganador: Santiago con 27 puntos
#
# Tabla de posiciones:
# Valentina {'puntaje_total': 124, 'rondas_ganadas': 2, 'mejor_ronda': 26, 'rondas_jugadas': 5}
# Mateo {'puntaje_total': 117, 'rondas_ganadas': 0, 'mejor_ronda': 26, 'rondas_jugadas': 5}
# Camila {'puntaje_total': 116, 'rondas_ganadas': 1, 'mejor_ronda': 26, 'rondas_jugadas': 5}
# Santiago {'puntaje_total': 115, 'rondas_ganadas': 1, 'mejor_ronda': 27, 'rondas_jugadas': 5}
# Lucía {'puntaje_total': 118, 'rondas_ganadas': 1, 'mejor_ronda': 27, 'rondas_jugadas': 5}
# ('Entrada', 'Camila', 26, {'Valentina': {'puntaje_total': 24, 'rondas_ganadas': 0, 'mejor_ronda': 24, 'rondas_jugadas': 1}, 'Mateo': {'puntaje_total': 22, 'rondas_ganadas': 0, 'mejor_ronda': 22, 'rondas_jugadas': 1}, 'Camila': {'puntaje_total': 26, 'rondas_ganadas': 1, 'mejor_ronda': 26, 'rondas_jugadas': 1}, 'Santiago': {'puntaje_total': 19, 'rondas_ganadas': 0, 'mejor_ronda': 19, 'rondas_jugadas': 1}, 'Lucía': {'puntaje_total': 24, 'rondas_ganadas': 0, 'mejor_ronda': 24, 'rondas_jugadas': 1}})

# %%
print("\nTABLA FINAL")

for p, d in tabla_final.items():
    print(p, d)
# Out:
# TABLA FINAL
# Valentina {'puntaje_total': 124, 'rondas_ganadas': 2, 'mejor_ronda': 26, 'rondas_jugadas': 5}
# Mateo {'puntaje_total': 117, 'rondas_ganadas': 0, 'mejor_ronda': 26, 'rondas_jugadas': 5}
# Camila {'puntaje_total': 116, 'rondas_ganadas': 1, 'mejor_ronda': 26, 'rondas_jugadas': 5}
# Santiago {'puntaje_total': 115, 'rondas_ganadas': 1, 'mejor_ronda': 27, 'rondas_jugadas': 5}
# Lucía {'puntaje_total': 118, 'rondas_ganadas': 1, 'mejor_ronda': 27, 'rondas_jugadas': 5}
